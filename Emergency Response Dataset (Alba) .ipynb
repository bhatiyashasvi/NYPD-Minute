# %%
library(dplyr)
library(jsonlite)
library(ggplot2)
library(readr)
library(dplyr)
library(stringr)
library(tidyr)
library(ggplot2)
library(httr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# trying to load data through the url
# the code works but only returns 1000 out of 11k rows

# emergency <- 'https://data.cityofnewyork.us/resource/pasr-j7fb.json'
# r <- GET(emergency)
# emergency <- df <- fromJSON(content(r, "text"))

# %% [markdown]
# **Loading the Emergency Response Dataset**

# %%
emergency <- read.csv("/content/emergency_response.csv")

# %% [markdown]
# **Performing general data analysis and clean up**

# %%
# the first few rows and column names

head(emergency)
# Out:
#   Incident.Type                Location                      Borough
# 1 Utility-Water Main           136-17 72 Avenue              Queens
# 2 Structural-Sidewalk Collapse 927 Broadway                  Manhattan
# 3 Utility-Other                                              Manhattan
# 4 Administration-Other         Seagirt Blvd & Beach 9 Street Queens
# 5 Law Enforcement-Other                                      Brooklyn
# 6 Utility-Water Main           2-17 54 Avenue                Queens
#   Creation.Date          Closed.Date Latitude Longitude
# 1 01/16/2017 01:13:38 PM             40.71400 -73.82999
# 2 10/29/2016 12:13:31 PM             40.71442 -74.00608
# 3 11/22/2016 08:53:17 AM                   NA        NA
# 4 11/14/2016 03:53:54 PM             40.71400 -73.82999
# 5 10/29/2016 05:35:28 PM                   NA        NA
# 6 12/02/2016 04:40:13 PM             40.71400 -73.82999

# %%
counts_by_borough <- emergency %>%
  group_by(Borough) %>%
  summarise(count = n())

# %%
#summary of the type of variables

glimpse(emergency)
# Out:
# Rows: 11,750
# Columns: 7
# $ Incident.Type <chr> "Utility-Water Main", "Structural-Sidewalk Collapse", "U…
# $ Location      <chr> "136-17 72 Avenue", "927 Broadway", "", "Seagirt Blvd & …
# $ Borough       <chr> "Queens", "Manhattan", "Manhattan", "Queens", "Brooklyn"…
# $ Creation.Date <chr> "01/16/2017 01:13:38 PM", "10/29/2016 12:13:31 PM", "11/…
# $ Closed.Date   <chr> "", "", "", "", "", "", "", "", "", "", "", "11/30/2016 …
# $ Latitude      <dbl> 40.71400, 40.71442, NA, 40.71400, NA, 40.71400, 40.71442…
# $ Longitude     <dbl> -73.82999, -74.00608, NA, -73.82999, NA, -73.82999, -74.…

# %%
# summary statistics
# notice NA values for Latitude and Longitude

summary(emergency)
# Out:
#  Incident.Type        Location           Borough          Creation.Date
#  Length:11750       Length:11750       Length:11750       Length:11750
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  Closed.Date           Latitude       Longitude
#  Length:11750       Min.   :40.50   Min.   :-74.25
#  Class :character   1st Qu.:40.68   1st Qu.:-73.99
#  Mode  :character   Median :40.73   Median :-73.95
#                     Mean   :40.73   Mean   :-73.93
#                     3rd Qu.:40.77   3rd Qu.:-73.90
#                     Max.   :40.91   Max.   : 74.07
#                     NA's   :1625    NA's   :1625

# %%
# checking for duplicates
duplicated(emergency_response)

# duplicates exist throughout the dataset but noot sure if they will be a problem
# Out:
#     [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
#    [25] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE
#    [37] FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE FALSE  TRUE  TRUE  TRUE FALSE
#    [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE FALSE
#    [61] FALSE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE FALSE FALSE  TRUE  TRUE
#    [73] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [85]  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE
#    [97] FALSE  TRUE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE
#   [109] FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE
#   [121] FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
#   [133]  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE
# ...

# %%
# Out:
# 'data.frame':	11750 obs. of  7 variables:
#  $ Incident.Type: chr  "Utility-Water Main" "Structural-Sidewalk Collapse" "Utility-Other" "Administration-Other" ...
#  $ Location     : chr  "136-17 72 Avenue" "927 Broadway" "" "Seagirt Blvd & Beach 9 Street" ...
#  $ Borough      : chr  "Queens" "Manhattan" "Manhattan" "Queens" ...
#  $ Creation.Date: chr  "01/16/2017 01:13:38 PM" "10/29/2016 12:13:31 PM" "11/22/2016 08:53:17 AM" "11/14/2016 03:53:54 PM" ...
#  $ Closed.Date  : chr  "" "" "" "" ...
#  $ Latitude     : num  40.7 40.7 NA 40.7 NA ...
#  $ Longitude    : num  -73.8 -74 NA -73.8 NA ...
